# %% [markdown]
# # 1. Right Angled Triangle

# %%
num = int(input("Enter the number: "))
for i in range(num):
    for j in range(i + 1):
        print("*", end=" ")
    print()
# Out:
# Enter the number: 7
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * * * *

# %% [markdown]
# # 2. Inverted Right Angled Triangle

# %%
num = int(input('Enter the number: '))

for i in range(num - 1, -1, -1):
    for j in range(i + 1):
        print('*', end=' ')
    print()
# Out:
# Enter the number: 7
# * * * * * * *
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# # 3. Centered Pyramid Pattern

# %%
num = int(input("Enter the number: "))

for i in range(1, num + 1):
    for j in range(num - i):
        print(" ", end=" ")
    for k in range(1, i * 2):
        print("*", end=" ")
    print()
# Out:
# Enter the number: 8
#               *
#             * * *
#           * * * * *
#         * * * * * * *
#       * * * * * * * * *
#     * * * * * * * * * * *
#   * * * * * * * * * * * * *
# * * * * * * * * * * * * * * *

# %% [markdown]
# # 4. Inverted Centered Pyramid Pattern

# %%
num=int(input('Enter the number: '))
print('Enter the number: 6')

for i in range (num,0,-1):
    for j in range(num-i):
        print(' ',end=' ')
    for k in range(1,i*2):
        print('*',end=' ')
    print()
# Out:
# Enter the number: 6
# * * * * * * * * * * *
#   * * * * * * * * *
#     * * * * * * *
#       * * * * *
#         * * *
#           *
